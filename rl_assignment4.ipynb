# %% [markdown]
# <a href="https://colab.research.google.com/github/PeralaPranay/RL-Assignments/blob/main/rl_assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Assignment: Upper Confidence Bound for Multi-Armed Bandit**

# %% [markdown]
# **ObjectiveImplement the Upper Confidence Bound (UCB) for a Multi-Armed Bandit problem and estimate the future reward (Q-value) of each machine using the incremental sample-average method.**

# %%
import math

machines = ['A', 'B', 'C']

N_play = 10

N = {machine: 0 for machine in machines}
R = {machine: [] for machine in machines}
Q = {machine: 0.0 for machine in machines}
UCB = {machine: 0.0 for machine in machines}

total_reward = 0

print("Upper Confidence Bound Multi-Armed Bandit")
print("-" * 50)

for t in range(1, N_play + 1):

    print(f"\nPlay {t}")
    for machine in machines:
        if N[machine] == 0:
            UCB[machine] = float('inf')
        else:
            UCB[machine] = Q[machine] + math.sqrt(
                (2 * math.log(t)) / N[machine]
            )
    print("\nUCB Values:")
    for machine in machines:
        if UCB[machine] == float('inf'):
            print(f"{machine}: Infinity")
        else:
            print(f"{machine}: {UCB[machine]:.3f}")
    selected_machine = max(machines, key=lambda x: UCB[x])

    print(f"\nPlay with machine {selected_machine}")
    reward = float(input("Enter reward: "))
    N[selected_machine] += 1
    R[selected_machine].append(reward)
    Q[selected_machine] = Q[selected_machine] + (
        (reward - Q[selected_machine]) / N[selected_machine]
    )
    total_reward += reward

    print(f"Updated Q-value of {selected_machine}: "
          f"{Q[selected_machine]:.3f}")

print("\n" + "=" * 60)
print("FINAL RESULTS")
print("=" * 60)

print(f"{'Machine':<10}{'N':<10}{'Rewards':<25}{'UCB':<12}{'Q-value'}")
print("-" * 75)

for machine in machines:

    if UCB[machine] == float('inf'):
        ucb_value = "Infinity"
    else:
        ucb_value = f"{UCB[machine]:.3f}"

    print(
        f"{machine:<10}"
        f"{N[machine]:<10}"
        f"{str(R[machine]):<25}"
        f"{ucb_value:<12}"
        f"{Q[machine]:.3f}"
    )

print("-" * 75)
print(f"\nTotal Reward Received = {total_reward}")
# Out:
# Upper Confidence Bound Multi-Armed Bandit
# --------------------------------------------------
#
# Play 1
#
# UCB Values:
# A: Infinity
# B: Infinity
# C: Infinity
#
# Play with machine A
# Enter reward: 3
# Updated Q-value of A: 3.000
#
# Play 2
#
# UCB Values:
# A: 4.177
# B: Infinity
# C: Infinity
#
# Play with machine B
# Enter reward: 6
# Updated Q-value of B: 6.000
#
# Play 3
#
# UCB Values:
# A: 4.482
# B: 7.482
# C: Infinity
#
# Play with machine C
# Enter reward: 4
# Updated Q-value of C: 4.000
#
# Play 4
#
# UCB Values:
# A: 4.665
# B: 7.665
# C: 5.665
#
# Play with machine B
# Enter reward: 7
# Updated Q-value of B: 6.500
#
# Play 5
#
# UCB Values:
# A: 4.794
# B: 7.769
# C: 5.794
#
# Play with machine B
# Enter reward: 5
# Updated Q-value of B: 6.000
#
# Play 6
#
# UCB Values:
# A: 4.893
# B: 7.093
# C: 5.893
#
# Play with machine B
# Enter reward: 8
# Updated Q-value of B: 6.500
#
# Play 7
#
# UCB Values:
# A: 4.973
# B: 7.486
# C: 5.973
#
# Play with machine B
# ...
