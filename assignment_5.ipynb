# %% [markdown]
# <a href="https://colab.research.google.com/github/PeralaPranay/RL-Assignments/blob/main/assignment_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gymnasium[classic-control]
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 64.4 MB/s eta 0:00:00
# ...

# %%
import gymnasium as gym

# %%
import gymnasium as gym


def random_agent(env_name, episodes=5):

    env = gym.make(env_name)

    print("\n====================================")
    print("Environment:", env_name)
    print("====================================")

    print("Action Space:", env.action_space)
    print("Observation Space:", env.observation_space)

    rewards = []

    for episode in range(episodes):


        state, info = env.reset()

        total_reward = 0
        steps = 0

        while True:

            action = env.action_space.sample()


            next_state, reward, terminated, truncated, info = env.step(action)


            total_reward += reward
            steps += 1


            state = next_state


            if terminated or truncated:
                break

        rewards.append(total_reward)

        print("Episode:", episode + 1)
        print("Total Reward:", total_reward)
        print("Steps:", steps)

    average_reward = sum(rewards) / len(rewards)

    print("\nEpisode Rewards:", rewards)
    print("Average Reward:", average_reward)

    env.close()

# %%
random_agent("CartPole-v1", 5)
# Out:
# ...
# Environment: CartPole-v1
# ...
# Action Space: Discrete(2)
# Observation Space: Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)
# Episode: 1
# Total Reward: 18.0
# Steps: 18
# Episode: 2
# Total Reward: 37.0
# Steps: 37
# Episode: 3
# Total Reward: 30.0
# Steps: 30
# Episode: 4
# Total Reward: 17.0
# Steps: 17
# Episode: 5
# Total Reward: 27.0
# Steps: 27
#
# Episode Rewards: [18.0, 37.0, 30.0, 17.0, 27.0]
# Average Reward: 25.8

# %%
random_agent("MountainCar-v0", 5)
# Out:
# ...
# Environment: MountainCar-v0
# ...
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Episode: 1
# Total Reward: -200.0
# Steps: 200
# Episode: 2
# Total Reward: -200.0
# Steps: 200
# Episode: 3
# Total Reward: -200.0
# Steps: 200
# Episode: 4
# Total Reward: -200.0
# Steps: 200
# Episode: 5
# Total Reward: -200.0
# Steps: 200
#
# Episode Rewards: [-200.0, -200.0, -200.0, -200.0, -200.0]
# Average Reward: -200.0

# %%
random_agent("FrozenLake-v1", 5)
# Out:
# ...
# Environment: FrozenLake-v1
# ...
# Action Space: Discrete(4)
# Observation Space: Discrete(16)
# Episode: 1
# Total Reward: 0
# Steps: 4
# Episode: 2
# Total Reward: 0
# Steps: 2
# Episode: 3
# Total Reward: 0
# Steps: 6
# Episode: 4
# Total Reward: 0
# Steps: 2
# Episode: 5
# Total Reward: 0
# Steps: 7
#
# Episode Rewards: [0, 0, 0, 0, 0]
# Average Reward: 0.0
