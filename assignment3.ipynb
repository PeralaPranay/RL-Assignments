# %% [markdown]
# <a href="https://colab.research.google.com/github/PeralaPranay/RL-Assignments/blob/main/assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

machines = ['A', 'B', 'C']

N_play = 10

epsilon = 0.2

N = {'A': 0, 'B': 0, 'C': 0}
R = {'A': 0, 'B': 0, 'C': 0}
Q = {'A': 0, 'B': 0, 'C': 0}

total_reward = 0


for play in range(1, N_play + 1):

    r = random.random()


    max_Q = max(Q.values())

    best_machines = [m for m in machines if Q[m] == max_Q]

    if r < epsilon:

        exploration_machines = [
            m for m in machines if m not in best_machines
        ]

        selected_machine = random.choice(exploration_machines)

        decision = "Exploration"

    else:

        selected_machine = random.choice(best_machines)

        decision = "Exploitation"

    print("\nPlay", play)
    print("Random number:", round(r, 4))
    print("Decision:", decision)
    print("Play with machine", selected_machine)

    reward = float(input("Enter reward: "))


    N[selected_machine] += 1

    R[selected_machine] += reward


    Q[selected_machine] = (
        Q[selected_machine]
        + (1 / N[selected_machine])
        * (reward - Q[selected_machine])
    )

    total_reward += reward

    print("Updated Q-value of", selected_machine, "=",
          round(Q[selected_machine], 2))


print("\n" + "=" * 50)
print("FINAL RESULTS")
print("=" * 50)

print("\nMachine\tN\tR\tQ")

for machine in machines:
    print(
        machine,
        "\t",
        N[machine],
        "\t",
        R[machine],
        "\t",
        round(Q[machine], 2)
    )

print("\nTotal Reward =", total_reward)
# Out:
# Play 1
# Random number: 0.7079
# Decision: Exploitation
# Play with machine B
# Enter reward: 6
# Updated Q-value of B = 6.0
#
# Play 2
# Random number: 0.5741
# Decision: Exploitation
# Play with machine B
# Enter reward: 7
# Updated Q-value of B = 6.5
#
# Play 3
# Random number: 0.8537
# Decision: Exploitation
# Play with machine B
# Enter reward: 5
# Updated Q-value of B = 6.0
#
# Play 4
# Random number: 0.6095
# Decision: Exploitation
# Play with machine B
# Enter reward: 8
# Updated Q-value of B = 6.5
#
# Play 5
# Random number: 0.6964
# Decision: Exploitation
# Play with machine B
# Enter reward: 6
# Updated Q-value of B = 6.4
#
# Play 6
# Random number: 0.8556
# Decision: Exploitation
# Play with machine B
# Enter reward: 7
# Updated Q-value of B = 6.5
#
# Play 7
# Random number: 0.9508
# Decision: Exploitation
# Play with machine B
# Enter reward: 5
# Updated Q-value of B = 6.29
#
# Play 8
# Random number: 0.3149
# Decision: Exploitation
# Play with machine B
# Enter reward: 8
# Updated Q-value of B = 6.5
#
# Play 9
# Random number: 0.8677
# Decision: Exploitation
# Play with machine B
# Enter reward: 6
# Updated Q-value of B = 6.44
#
# Play 10
# Random number: 0.6567
# Decision: Exploitation
# Play with machine B
# Enter reward: 7
# Updated Q-value of B = 6.5
#
# ==================================================
# FINAL RESULTS
# ==================================================
#
# Machine	N	R	Q
# A 	 0 	 0 	 0
# B 	 10 	 65.0 	 6.5
# C 	 0 	 0 	 0
#
# Total Reward = 65.0
