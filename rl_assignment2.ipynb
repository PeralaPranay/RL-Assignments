# %% [markdown]
# <a href="https://colab.research.google.com/github/PeralaPranay/RL-Assignments/blob/main/rl_assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
machines = ['A', 'B', 'C']

N_play = 10

epsilon = 0.2

N = {
    'A': 0,
    'B': 0,
    'C': 0
}

R = {
    'A': [],
    'B': [],
    'C': []
}

Q = {
    'A': 0.0,
    'B': 0.0,
    'C': 0.0
}

total_reward = 0
for play in range(1, N_play + 1):

    r = random.random()

    if r < epsilon:
        # Exploration
        machine = random.choice(machines)
        decision = "Exploration"
    else:
        # Exploitation
        max_q = max(Q.values())

        best_machines = [
            m for m in machines
            if Q[m] == max_q
        ]

        machine = random.choice(best_machines)
        decision = "Exploitation"

    print(f"\nPlay {play}")
    print(f"Random number = {r:.2f}")
    print(f"Decision = {decision}")
    print(f"Selected Machine = {machine}")
    reward = float(input("Enter reward: "))

    N[machine] += 1
    R[machine].append(reward)

    Q[machine] = Q[machine] + (
        (reward - Q[machine]) / N[machine]
    )

    total_reward += reward
    print(f"N({machine}) = {N[machine]}")
    print(f"Q({machine}) = {Q[machine]:.2f}")
print("\n========== FINAL RESULTS ==========")

print("\nN Table:")
for machine in machines:
    print(f"N({machine}) = {N[machine]}")

print("\nR Table:")
for machine in machines:
    print(f"R({machine}) = {R[machine]}")

print("\nQ Table:")
for machine in machines:
    print(f"Q({machine}) = {Q[machine]:.2f}")

print(f"\nTotal Reward after 10 plays = {total_reward:g}")
# Out:
# Play 1
# Random number = 0.69
# Decision = Exploitation
# Selected Machine = B
# Enter reward: 3
# N(B) = 1
# Q(B) = 3.00
#
# Play 2
# Random number = 0.12
# Decision = Exploration
# Selected Machine = A
# Enter reward: 4
# N(A) = 1
# Q(A) = 4.00
#
# Play 3
# Random number = 0.85
# Decision = Exploitation
# Selected Machine = A
# Enter reward: 2
# N(A) = 2
# Q(A) = 3.00
#
# Play 4
# Random number = 0.70
# Decision = Exploitation
# Selected Machine = A
# Enter reward: 5
# N(A) = 3
# Q(A) = 3.67
#
# Play 5
# Random number = 0.15
# Decision = Exploration
# Selected Machine = C
# Enter reward: 4
# N(C) = 1
# Q(C) = 4.00
#
# Play 6
# Random number = 0.79
# Decision = Exploitation
# Selected Machine = C
# Enter reward: 3
# N(C) = 2
# Q(C) = 3.50
#
# Play 7
# Random number = 0.13
# Decision = Exploration
# Selected Machine = B
# Enter reward: 6
# N(B) = 2
# Q(B) = 4.50
#
# Play 8
# Random number = 0.62
# Decision = Exploitation
# Selected Machine = B
# Enter reward: 7
# N(B) = 3
# ...
